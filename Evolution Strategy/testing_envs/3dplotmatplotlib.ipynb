# %%
from mpl_toolkits import mplot3d

from mpl_toolkits.mplot3d import axes3d    
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

fig = plt.figure()
ax = plt.axes(projection="3d")

# %matplotlib notebook
plt.show()

# %%
x1 = -5; y1 = 0

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))
    #return -1*(x**2 - 1)**2 - ((x**2)*y-x-1)**2

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
X, Y = np.meshgrid(x, y)
Z = z_function(X, Y)

ax = plt.axes(projection="3d")
ax.plot_wireframe(X, Y, Z, color='green')
ax.scatter(x1,y1,z_function(x1,y1), s = 100, color='red')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

plt.contourf(X,Y,Z, levels=[*np.linspace(-1,1,10)])
plt.scatter(x1,y1,s = 50, color='red')
plt.show()

# %%
plt.contourf(X,Y,Z, levels=[*np.linspace(-1,1,10)])
plt.scatter(x,y,s = 50, color='red')
plt.show()
# %matplotlib inline

# %%
from random import uniform
import time
from IPython.display import display, clear_output

def black_box():
    i = 1
    while True:
        clear_output(wait=True)
        data = [np.random.random() for _ in range(100)]
        plt.plot(data)
        plt.show()
        display('Iteration '+str(i)+' Score: '+str(uniform(0, 1)))
        time.sleep(1)
        i += 1
black_box()

# %%
def get_random(best_para, low, high):
    flag = True
    while flag:
        x_temp = np.random.randn() + best_para[0]
        y_temp = np.random.randn() + best_para[1]
        if x_temp >= low and x_temp <= high and y_temp >= low and y_temp <= high:
            flag = False
        else:
            continue
    return np.array([x_temp, y_temp],dtype=np.float32)

# %%
low = -6
high = 6
sigma = 0.5
batch_size = 10
x1 = np.random.randint(low,high)
y1 = np.random.randint(low,high)
nos = 10
best_para = np.array([x1,y1], dtype=np.float32)*sigma
for i in range(nos):
   memory = [best_para + sigma*get_random(best_para,low,high) for _ in range(batch_size)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-2f7e07ecc6bd> in <module>
#       8 best_para = np.array([x1,y1], dtype=np.float32)*sigma
#       9 for i in range(nos):
# ---> 10    memory = [best_para + sigma*get_random(best_para) for _ in range(batch_size)]
#
# <ipython-input-102-2f7e07ecc6bd> in <listcomp>(.0)
#       8 best_para = np.array([x1,y1], dtype=np.float32)*sigma
#       9 for i in range(nos):
# ---> 10    memory = [best_para + sigma*get_random(best_para) for _ in range(batch_size)]
#
# NameError: name 'get_random' is not defined

# %%
# Out:
# array([-4,  2])

# %%
np.array([x1,y1], dtype=np.float32) + np.array([3,4],dtype=np.float32)
# Out:
# array([2., 6.], dtype=float32)

# %%
np.array([x1,y1], dtype=np.float32) + np.array([3,4],dtype=np.float32)
